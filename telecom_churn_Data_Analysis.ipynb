# %% [markdown]
# <a href="https://colab.research.google.com/github/LAXMAN7795/Data-Analysis/blob/main/telecom_churn_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

pd.set_option("display.precision", 2)

# %%
DATA_URL = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/"

# %%
df = pd.read_csv(DATA_URL+"telecom_churn.csv").head()
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (5, 20)

# %%
print(df.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   5 non-null      object
#  1   Account length          5 non-null      int64
#  2   Area code               5 non-null      int64
#  3   International plan      5 non-null      object
#  4   Voice mail plan         5 non-null      object
#  5   Number vmail messages   5 non-null      int64
#  6   Total day minutes       5 non-null      float64
#  7   Total day calls         5 non-null      int64
#  8   Total day charge        5 non-null      float64
#  9   Total eve minutes       5 non-null      float64
#  10  Total eve calls         5 non-null      int64
#  11  Total eve charge        5 non-null      float64
#  12  Total night minutes     5 non-null      float64
#  13  Total night calls       5 non-null      int64
# ...

# %%
df["Churn"]=df["Churn"].astype('int64')#to change the Churn datatype from bool to int64
df
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count            5.00       5.00                   5.00               5.00
# mean           106.20     413.60                  10.20             227.24
# std             26.88       3.13                  13.97              60.98
# min             75.00     408.00                   0.00             161.60
# 25%             84.00     415.00                   0.00             166.70
# 50%            107.00     415.00                   0.00             243.40
# 75%            128.00     415.00                  25.00             265.10
# max            137.00     415.00                  26.00             299.40
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count             5.00              5.00               5.00             5.00
# mean            106.20             38.63             144.86           104.40
# ...

# %%
df.describe(include=['object','bool'])#In order to see statistics on non-numerical features
# Out:
#        State International plan Voice mail plan
# count      5                  5               5
# unique     4                  2               2
# top       OH                 No              No
# freq       2                  3               3

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    5
# Name: count, dtype: int64

# %%
df["Churn"].count()
# Out:
# 5

# %%
df.sort_values(by="Total day charge",ascending=False).head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 3    OH              84        408                Yes              No
# 0    KS             128        415                 No             Yes
# 2    NJ             137        415                 No              No
# 4    OK              75        415                Yes              No
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 3                      0              299.4               71
# 0                     25              265.1              110
# 2                      0              243.4              114
# 4                      0              166.7              113
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3             50.90               61.9               88              5.26
# ...

# %%
df.sort_values(by=["Total day calls","Total night calls"],ascending=[False,False]).head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 4    OK              75        415                Yes              No
# 0    KS             128        415                 No             Yes
# 3    OH              84        408                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 1                     26              161.6              123
# 2                      0              243.4              114
# 4                      0              166.7              113
# 0                     25              265.1              110
# 3                      0              299.4               71
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1             27.47              195.5              103             16.62
# ...

# %%
df['Account length'].mean()
# Out:
# 106.2

# %%
df.select_dtypes(include=np.number)#to select only numeric columns
# Out:
#    Account length  Area code  Number vmail messages  Total day minutes  \
# 0             128        415                     25              265.1
# 1             107        415                     26              161.6
# 2             137        415                      0              243.4
# 3              84        408                      0              299.4
# 4              75        415                      0              166.7
#
#    Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# 0              110             45.07              197.4               99
# 1              123             27.47              195.5              103
# 2              114             41.38              121.2              110
# 3               71             50.90               61.9               88
# 4              113             28.34              148.3              122
#
#    Total eve charge  Total night minutes  Total night calls  \
# ...

# %%
#How much time (on average) do churned users spend on the phone during daytime?
df[df['Churn']==0]['Total day minutes'].mean()
# Out:
# 227.24

# %%
df['Churn']=df['Churn'].astype('bool')
df
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#What is the maximum length of international calls among loyal users (Churn == 0) who do not have an international plan?
df[(df['Churn']==0)&(df['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 13.7

# %%
df.loc[0:5,"State":'Voice mail plan']
# Out:
#   State  Account length  Area code International plan Voice mail plan
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No

# %%
df.iloc[0:4,0:7]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
#
#    Number vmail messages  Total day minutes
# 0                     25              265.1
# 1                     26              161.6
# 2                      0              243.4
# 3                      0              299.4

# %%
df[:4]#how many rows
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# ...

# %%
df[4:]#specific column
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 4                       3  False

# %%
df[-1:]#last
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 4                       3  False

# %%
import pandas as pd
DATA_URL = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/"
df = pd.read_csv(DATA_URL+"telecom_churn.csv")
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# to apply all columns
import numpy as np
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                      True
# dtype: object

# %%
df[df['State'].apply(lambda state:state[0]=='W')].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 9     WV             141        415                Yes             Yes
# 26    WY              57        408                 No             Yes
# 44    WI              64        510                 No              No
# 49    WY              97        415                 No             Yes
# 54    WY              87        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 9                      37              258.6               84
# 26                     39              213.0              115
# 44                      0              154.0               67
# 49                     24              133.2              135
# 54                      0              151.0               83
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 9              43.96              222.0              111             18.87
# ...

# %%
#map method can be used to replace values in a column by passing a dictionary of the form {old_value: new_value} as its argument
change = {'Yes':True,'No':False}
df['International plan']=df['International plan'].map(change)
df
# Out:
#      State  Account length  Area code  International plan Voice mail plan  \
# 0       KS             128        415               False             Yes
# 1       OH             107        415               False             Yes
# 2       NJ             137        415               False              No
# 3       OH              84        408                True              No
# 4       OK              75        415                True              No
# ...    ...             ...        ...                 ...             ...
# 3328    AZ             192        415               False             Yes
# 3329    WV              68        415               False              No
# 3330    RI              28        510               False              No
# 3331    CT             184        510                True              No
# 3332    TN              74        415               False             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#same thing can be done with the replace method.
df=df.replace({"Voice mail plan":change})
df
# Out:
# <ipython-input-28-8dd1644853e2>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace({"Voice mail plan":change})
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# 3328    AZ             192        415               False             True
# ...

# %%
#group df.groupby(by=grouping_columns)[columns_to_show].function()
columns_to_show = ["Total day minutes", "Total eve minutes", "Total night minutes"]
df.groupby(['Churn'])[columns_to_show].describe(percentiles=[])
# Out:
#       Total day minutes                                   Total eve minutes  \
#                   count    mean    std  min    50%    max             count
# Churn
# False            2850.0  175.18  50.18  0.0  177.2  315.6            2850.0
# True              483.0  206.91  69.00  0.0  217.6  350.8             483.0
#
#                                          Total night minutes                 \
#          mean    std   min    50%    max               count    mean    std
# Churn
# False  199.04  50.29   0.0  199.6  361.8              2850.0  200.13  51.11
# True   212.41  51.73  70.9  211.3  363.7               483.0  205.23  47.13
#
#
#         min     50%    max
# Churn
# False  23.2  200.25  395.0
# True   47.4  204.80  354.9

# %%
columns_to_show = ["Total day minutes", "Total eve minutes", "Total night minutes"]
df.groupby(['Churn'])[columns_to_show].agg(["std","min","max"])
# Out:
#       Total day minutes             Total eve minutes               \
#                     std  min    max               std   min    max
# Churn
# False             50.18  0.0  315.6             50.29   0.0  361.8
# True              69.00  0.0  350.8             51.73  70.9  363.7
#
#       Total night minutes
#                       std   min    max
# Churn
# False               51.11  23.2  395.0
# True                47.13  47.4  354.9

# %%
#Summary tables
pd.crosstab(df['Churn'],df['International plan'])
# Out:
# International plan  False  True
# Churn
# False                2664    186
# True                  346    137

# %%
#pivot table
df.pivot_table(
    ["Total day calls", "Total eve calls", "Total night calls"],#columns
    ["Area code"],#rows
    aggfunc='mean'#function
)
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408                 100.50            99.79              99.04
# 415                 100.58           100.50             100.40
# 510                 100.10            99.67             100.60

# %%
# delete columns and rows
df.drop(["Total day calls", "Total eve calls"], axis=1, inplace=True)
# delete rows
df.drop([1, 2]).head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
# 5    AL             118        510                True            False
# 6    MA             121        510               False             True
#
#    Number vmail messages  Total day minutes  Total day charge  \
# 0                     25              265.1             45.07
# 3                      0              299.4             50.90
# 4                      0              166.7             28.34
# 5                      0              223.4             37.98
# 6                     24              218.2             37.09
#
#    Total eve minutes  Total eve charge  Total night minutes  \
# 0              197.4             16.78                244.7
# ...

# %%
pd.crosstab(df["Churn"],df["International plan"],margins=True)
# Out:
# International plan  False  True   All
# Churn
# False                2664   186  2850
# True                  346   137   483
# All                  3010   323  3333

# %%
# some imports to set up plotting
import matplotlib.pyplot as plt

# !pip install seaborn
import seaborn as sns

# import some nice vis settings
sns.set()
# Graphics in the Retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x="International plan",hue="Churn",data=df)
plt.show()

# %%
# Matplotlib forms basis for visualization in Python
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# We will use the Seaborn library
import seaborn as sns

sns.set()

# Graphics in SVG format are more sharp and legible
# %config InlineBackend.figure_format = 'svg'

# %%
DATA_URL = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/"
df = pd.read_csv(DATA_URL + "telecom_churn.csv")
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#The easiest way to take a look at the distribution of a numerical variable is to plot its histogram using the DataFrame’s method hist().
features = ["Total day minutes", "Total intl calls"]
df[features].hist(figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'Total day minutes'}>,
#         <Axes: title={'center': 'Total intl calls'}>]], dtype=object)

# %%
df[features].plot(
    kind="density",subplots=True,layout=(1,2),sharex=False,figsize=(10,4)
)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
sns.histplot(df["Total intl calls"],kde=True,stat="density")
# Out:
# <Axes: xlabel='Total intl calls', ylabel='Density'>

# %%
sns.boxplot(x="Total intl calls",data=df)
# Out:
# <Axes: xlabel='Total intl calls'>

# %%
_, axes = plt.subplots(1, 2, sharey=True, figsize=(6, 4))
sns.boxplot(data=df["Total intl calls"], ax=axes[0])
sns.violinplot(data=df["Total intl calls"], ax=axes[1]);

# %%
_, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
sns.countplot(x="Churn", data=df, ax=axes[0])
sns.countplot(x="Customer service calls", data=df, ax=axes[1]);

# %%
plt.scatter(df["Total day minutes"], df["Total night minutes"]);

# %%
sns.jointplot(x="Total day minutes", y="Total night minutes", data=df, kind="scatter");

# %%
sns.jointplot(
    x="Total day minutes", y="Total night minutes", data=df, kind="kde", color="g"
);

# %%
# `pairplot()` may become very slow with the SVG format
# %config InlineBackend.figure_format = 'png'
sns.pairplot(df[features]);
